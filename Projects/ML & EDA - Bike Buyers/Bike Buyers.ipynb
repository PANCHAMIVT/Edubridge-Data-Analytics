# %% [markdown]
# ## Bike Buyers- A Quick Insights

# %% [markdown]
# ### Abstract

# %% [markdown]
# This dataset has details of 1000 users from different backgrounds and output variable as  and whether or not they buy a bike. This data can be used for prediction models using Machine Learning Algorithms. Using this dataset for Data Cleaning, Exploration and Visualization.

# %% [markdown]
# ### Columns :

# %% [markdown]
# * ID
# * Marital Status
# * Gender
# * Income
# * Children
# * Education
# * Occupation
# * Home Owner
# * Cars
# * Commute Distance
# * Region
# * Age
# * Purchased Bike

# %% [markdown]
# ## Structure

# %% [markdown]
# * Part 1: Importing Libraries
# * Part 2: Reading the data
# * Part 3: Exploring the data
# * Part 4: Cleaning the data
# * part 5: Analysing and Visualization the data
# * part 6: Machine Learning Models Building
# * part 7: Conclusion

# %% [markdown]
# ## Importing The Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Reading and Viewing the Data

# %%
d=pd.read_csv('bike_buyers_clean.csv')
d
# Out:
#         ID Marital Status  Gender  Income  Children        Education  \
# 0    12496        Married  Female   40000         1        Bachelors
# 1    24107        Married    Male   30000         3  Partial College
# 2    14177        Married    Male   80000         5  Partial College
# 3    24381         Single    Male   70000         0        Bachelors
# 4    25597         Single    Male   30000         0        Bachelors
# ..     ...            ...     ...     ...       ...              ...
# 995  23731        Married    Male   60000         2      High School
# 996  28672         Single    Male   70000         4  Graduate Degree
# 997  11809        Married    Male   60000         2        Bachelors
# 998  19664         Single    Male  100000         3        Bachelors
# 999  12121         Single    Male   60000         3      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region  Age  \
# ...

# %% [markdown]
# ## Exploring the data

# %% [markdown]
# ## Shape of the Data

# %%
d.shape
# Out:
# (1000, 13)

# %% [markdown]
# ## Basic Information

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                1000 non-null   int64
#  1   Marital Status    1000 non-null   object
#  2   Gender            1000 non-null   object
#  3   Income            1000 non-null   int64
#  4   Children          1000 non-null   int64
#  5   Education         1000 non-null   object
#  6   Occupation        1000 non-null   object
#  7   Home Owner        1000 non-null   object
#  8   Cars              1000 non-null   int64
#  9   Commute Distance  1000 non-null   object
#  10  Region            1000 non-null   object
#  11  Age               1000 non-null   int64
#  12  Purchased Bike    1000 non-null   object
# dtypes: int64(5), object(8)
# memory usage: 101.7+ KB

# %% [markdown]
# ## Statistical Information

# %%
d.describe()
# Out:
#                  ID         Income     Children         Cars          Age
# count   1000.000000    1000.000000  1000.000000  1000.000000  1000.000000
# mean   19965.992000   56140.000000     1.908000     1.452000    44.190000
# std     5347.333948   31081.609779     1.626094     1.124705    11.353537
# min    11000.000000   10000.000000     0.000000     0.000000    25.000000
# 25%    15290.750000   30000.000000     0.000000     1.000000    35.000000
# 50%    19744.000000   60000.000000     2.000000     1.000000    43.000000
# 75%    24470.750000   70000.000000     3.000000     2.000000    52.000000
# max    29447.000000  170000.000000     5.000000     4.000000    89.000000

# %%
d.columns
# Out:
# Index(['ID', 'Marital Status', 'Gender', 'Income', 'Children', 'Education',
#        'Occupation', 'Home Owner', 'Cars', 'Commute Distance', 'Region', 'Age',
#        'Purchased Bike'],
#       dtype='object')

# %%
d.dtypes
# Out:
# ID                   int64
# Marital Status      object
# Gender              object
# Income               int64
# Children             int64
# Education           object
# Occupation          object
# Home Owner          object
# Cars                 int64
# Commute Distance    object
# Region              object
# Age                  int64
# Purchased Bike      object
# dtype: object

# %% [markdown]
# ## Cleaning the Dataset:
#
# - Check the null values
# - Check the duplicates
# - Droping unimportant column.

# %%
d.isnull().sum()
# Out:
# ID                  0
# Marital Status      0
# Gender              0
# Income              0
# Children            0
# Education           0
# Occupation          0
# Home Owner          0
# Cars                0
# Commute Distance    0
# Region              0
# Age                 0
# Purchased Bike      0
# dtype: int64

# %%
d.duplicated().sum()
# Out:
# 0

# %%
d.drop(["ID"], axis=1, inplace=True)

# %% [markdown]
# ### Get unique values for marital status

# %%
d['Marital Status'].unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
d["Purchased Bike"].value_counts()
# Out:
# No     519
# Yes    481
# Name: Purchased Bike, dtype: int64

# %% [markdown]
# ## Visualisation

# %% [markdown]
# ## Bike Purchase Trend According to Marital Status

# %%
marital_bike = d.groupby(['Marital Status'], as_index = False)['Purchased Bike'].count()

marital_bike.plot(kind = 'bar' , x = 'Marital Status' , y = 'Purchased Bike', figsize = (6 , 6) , color = 'red' , grid = True , width = 0.2 , rot = 0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### From the above plot we can see people who are married are more likely to purchase a bike.

# %% [markdown]
# ## Bike Purchase Trend According to Gender

# %%
fig, ax=plt.subplots(figsize=(9, 11))
ax=sns.countplot(x="Purchased Bike", data=d, hue='Gender', hue_order=['Male', 'Female'])

ax.set(xlabel='Purchased Bike', ylabel='Count of No/Yes',title="Count of People who Purchased the Bike and who Did't")
ax.xaxis.get_label().set_fontsize(10)
ax.yaxis.get_label().set_fontsize(10)

plt.show()

# %% [markdown]
# ##### There is only a slight difference between the genders when it comes to purchasing a bike.

# %% [markdown]
# ## Bike purchasing trend according to region

# %%
fig, ax=plt.subplots(figsize=(9, 6))
ax=sns.countplot(x="Purchased Bike", data=d, hue='Region')

ax.set(xlabel='Purchased Bike', ylabel='Count of No/Yes',title="Count of People who Purchased the Bike and who Did't")
ax.xaxis.get_label().set_fontsize(14)
ax.yaxis.get_label().set_fontsize(14)

plt.show()

# %% [markdown]
# ## Bike purchasing trend according to occupation

# %%
fig, ax=plt.subplots(figsize=(9, 6))
ax=sns.countplot(x="Purchased Bike", data=d, hue='Occupation', hue_order=['Professional', 'Skilled Manual', 'Clerical', 'Management', 'Manual'])

ax.set(xlabel='Purchased Bike', ylabel='Count of No/Yes',title="Count of People who Purchased the Bike and who Did't")
ax.xaxis.get_label().set_fontsize(14)
ax.yaxis.get_label().set_fontsize(14)

plt.show()

# %% [markdown]
# ## Bike Purchasing Trend According to Age

# %%
sns.histplot(x="Age", data=d, hue="Purchased Bike", multiple="dodge", shrink=0.8, bins=[20, 30, 40, 50, 60, 70, 80, 90], palette=sns.blend_palette(['red', 'green'], 2))
plt.show()

# %% [markdown]
# ## Bike Purchasing Trend According to Salary

# %%
sns.histplot(x="Income", data=d, hue="Purchased Bike", multiple="dodge", shrink=0.8, bins=[10000, 25000, 40000, 55000, 70000, 85000, 100000, 115000, 130000, 145000, 160000, 175000, 190000, 205000], palette=sns.blend_palette(['red', 'green'], 2))
plt.show()

# %% [markdown]
# ## Bike Purchasing Trend According to Education

# %%
fig, ax=plt.subplots(figsize=(11, 6))
sns.set_theme(style='white', palette=None)
sns.histplot(x="Education", data=d, hue="Purchased Bike", multiple="dodge", shrink=0.6, palette=sns.blend_palette(['red', 'green'], 2))
plt.show()

# %% [markdown]
# ## Bike Purchasing Trend According to Numbers of their Children

# %%
sns.histplot(x="Children", data=d, hue="Purchased Bike", multiple="dodge", shrink=0.8, bins=[0, 1, 2, 3, 4, 5, 6], palette=sns.blend_palette(['red', 'green'], 2))
plt.show()

# %% [markdown]
# ## Bike Purchasing Trend According to Number of Cars They Own

# %%
sns.histplot(x="Cars", data=d, hue="Purchased Bike", multiple="dodge", shrink=0.8, bins=[0, 1, 2, 3, 4, 5], palette=sns.blend_palette(['red', 'green'], 2))
plt.show()

# %% [markdown]
# ## Bike Purchasing Trend of Home Owners

# %%
sns.histplot(x="Home Owner", data=d, hue="Purchased Bike", multiple="dodge", shrink=0.2, palette=sns.blend_palette(['red', 'green'], 2))
plt.show()

# %% [markdown]
# ## Bike Purchasing Trend According to Commuting Distance

# %%
sns.histplot(x="Commute Distance", data=d, hue="Purchased Bike", multiple="dodge", shrink=0.8, bins=[0, 1, 2, 3, 4, 5, 6], palette=sns.blend_palette(['red', 'green'], 2))
plt.show()

# %% [markdown]
# ## Scatter plot Income vs Age

# %%
fig, ax=plt.subplots(figsize=(9, 6))
sns.scatterplot(x="Income", y="Age", data=d, hue="Purchased Bike", palette=sns.blend_palette(['red', 'green'], 2))
plt.show()

# %% [markdown]
# ## The max and min salary for those who purchased a bike

# %%
print('Max salary is:', d['Income'].max())
print('Min salary is:', d['Income'].min())
print('Mean salary is:', d['Income'].mean())


d['Income'].hist(bins = 10, color = 'red', alpha = 0.5 , figsize = (10 , 8) , grid = False)
plt.axvline(d['Income'].mean(), color = 'k', linestyle = 'dashed', linewidth = 2)
plt.title('Distribution of Income over bike purchases')
plt.show()
# Out:
# Max salary is: 170000
# Min salary is: 10000
# Mean salary is: 56140.0

# %% [markdown]
# ##### The average income is around 55K mark and the spread is consistent with few value towards the right tail.

# %%
sns.pairplot(d,hue="Purchased Bike", kind="reg", palette=sns.blend_palette(['red', 'green'], 2))
plt.show()

# %%
plt.figure()
sns.heatmap(d.corr(),annot=True)
plt.title("Heatmap of Correlation Matrix")
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# According to the analysis, the odds that a customer will buy a bike will Increase if:
#
# * People who are married are more likely to purchase a bike.
# * People who has Less children.
# * People who have a Professional occuptaion.
# * People who has Less cars.
# * People who has a Low commute distance.
# * People who is living in the North American Region.

# %%
# replacing values With 1 and 0 data.
# Taking a variables.
A = {"Married" :0, "Single" :1, "No Data" :2}
B = {"Male" :1, "Female" :0, "No Data" :2}
C = {"Bachelors" :0, "Partial College" :1,"High School" :2, "Graduate Degree" :3, "Partial High School" :4}
D = {"Professional" :0, "Skilled Manual" :1,"Clerical" :2, "Management" :3, "Manual" :4}
E = {"Yes" :1, "No" :0, "No Data" :2}
F = {"0-1 Miles" :0, "5-10 Miles" :1,"1-2 Miles" :2, "2-5 Miles" :3, "10+ Miles" :4}
G = {"North America" :0, "Europe" :1, "Pacific" :2}
H = {"Yes" :1, "No" :0}

# %%
# Replacing the the values In Dataframe.
d = d.replace({'Marital Status': A})
d = d.replace({'Gender': B})
d = d.replace({'Education': C})
d = d.replace({'Occupation': D})
d = d.replace({'Home Owner': E})
d = d.replace({'Commute Distance': F})
d = d.replace({'Region': G})
d = d.replace({'Purchased Bike': H})
# Printing Dataframe
d
# Out:
#      Marital Status  Gender  Income  Children  Education  Occupation  \
# 0                 0       0   40000         1          0           1
# 1                 0       1   30000         3          1           2
# 2                 0       1   80000         5          1           0
# 3                 1       1   70000         0          0           0
# 4                 1       1   30000         0          0           2
# ..              ...     ...     ...       ...        ...         ...
# 995               0       1   60000         2          2           0
# 996               1       1   70000         4          3           0
# 997               0       1   60000         2          0           1
# 998               1       1  100000         3          0           3
# 999               1       1   60000         3          2           0
#
#      Home Owner  Cars  Commute Distance  Region  Age  Purchased Bike
# 0             1     0                 0       1   42               0
# ...

# %% [markdown]
# ## Taking the variables

# %%
x = d.drop(['Purchased Bike'],axis=1)
x
# Out:
#      Marital Status  Gender  Income  Children  Education  Occupation  \
# 0                 0       0   40000         1          0           1
# 1                 0       1   30000         3          1           2
# 2                 0       1   80000         5          1           0
# 3                 1       1   70000         0          0           0
# 4                 1       1   30000         0          0           2
# ..              ...     ...     ...       ...        ...         ...
# 995               0       1   60000         2          2           0
# 996               1       1   70000         4          3           0
# 997               0       1   60000         2          0           1
# 998               1       1  100000         3          0           3
# 999               1       1   60000         3          2           0
#
#      Home Owner  Cars  Commute Distance  Region  Age
# 0             1     0                 0       1   42
# ...

# %%
y = d['Purchased Bike']
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 995    1
# 996    1
# 997    1
# 998    0
# 999    1
# Name: Purchased Bike, Length: 1000, dtype: int64

# %% [markdown]
# ## Various Types Of Machine Learning Models Building.

# %% [markdown]
# #### Training the data with Some of the ML approaches:
#
# - Logistic Regression
# - Decision Tree Classifier
# - Random Forest Classifier
# - GaussianNB
# - XGBoost Classifier

# %% [markdown]
# #### ML approach Functions
#
# - Model fitting
# - Predicting using test
# - Accuracy score
# - confusion matrix
# - Classification report

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix,plot_confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
import xgboost as xgb

# %%
# Running The train_test_split function on (x,y and taking 0.2[20%] data as test data)

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=112)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (800, 11)
# (800,)
# (200, 11)
# (200,)

# %% [markdown]
# ##  Logistic Regression

# %% [markdown]
# Logistic regression is a statistical analysis method to predict a binary outcome, such as yes or no, based on prior observations of a data set. A logistic regression model predicts a dependent data variable by analyzing the relationship between one or more existing independent variables.

# %%
logistic_model = LogisticRegression()
logistic_model.fit(x_train,y_train)
logistic_model.score(x_test,y_test)
# Out:
# 0.525

# %%
y_predict = logistic_model.predict(x_test)
performance = confusion_matrix(y_test,y_predict)

plot_confusion_matrix(logistic_model,x_test,y_test)
plt.show()

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.83      0.63        96
#            1       0.61      0.24      0.34       104
#
#     accuracy                           0.53       200
#    macro avg       0.56      0.54      0.49       200
# weighted avg       0.56      0.53      0.48       200

# %% [markdown]
# ## Decision Tree Classifier

# %% [markdown]
# Decision Tree is a Supervised learning technique that can be used for both classification and Regression problems, but mostly it is preferred for solving Classification problems. It is a tree-structured classifier, where internal nodes represent the features of a dataset, branches represent the decision rules and each leaf node represents the outcome.

# %%
tr =DecisionTreeClassifier()
tr.fit(x_train, y_train)
tr.score(x_test,y_test)
# Out:
# 0.705

# %%
y_predict = tr.predict(x_test)
accuracy_score(y_test,y_predict)
# Out:
# 0.705

# %%
performance = confusion_matrix(y_test,y_predict)

plot_confusion_matrix(tr,x_test,y_test)
plt.show()

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.74      0.71        96
#            1       0.74      0.67      0.70       104
#
#     accuracy                           0.70       200
#    macro avg       0.71      0.71      0.70       200
# weighted avg       0.71      0.70      0.70       200

# %% [markdown]
# ## Random Forest Classifier

# %% [markdown]
# Random Forest is a classifier that contains a number of decision trees on various subsets of the given dataset and takes the average to improve the predictive accuracy of that dataset.The greater number of trees in the forest leads to higher accuracy and prevents the problem of overfitting.

# %%
rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
rfc.score(x_test,y_test)
# Out:
# 0.765

# %%
y_predict =rfc.predict(x_test)
performance = confusion_matrix(y_test,y_predict)

plot_confusion_matrix(rfc,x_test,y_test)
plt.show()

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.80      0.77        96
#            1       0.80      0.73      0.76       104
#
#     accuracy                           0.77       200
#    macro avg       0.77      0.77      0.76       200
# weighted avg       0.77      0.77      0.76       200

# %% [markdown]
# ## Naive Bayes Classifier

# %% [markdown]
# Naive Bayes Classifier is one of the simple and most effective Classification algorithms which helps in building the fast machine learning models that can make quick predictions.

# %%
gnb = GaussianNB()
gnb.fit(x_train,y_train)
gnb.score(x_test,y_test)
# Out:
# 0.63

# %%
y_predict = gnb.predict(x_test)

performance = confusion_matrix(y_test,y_predict)

plot_confusion_matrix(gnb,x_test,y_test)
plt.show()

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.60      0.61        96
#            1       0.64      0.65      0.65       104
#
#     accuracy                           0.63       200
#    macro avg       0.63      0.63      0.63       200
# weighted avg       0.63      0.63      0.63       200

# %% [markdown]
# ## XGB Classifier

# %% [markdown]
# XGBoost classifier is a Machine learning algorithm that is applied for structured and tabular data. XGBoost is an implementation of gradient boosted decision trees designed for speed and performance. XGBoost is an extreme gradient boost algorithm. And that means it’s a big Machine learning algorithm with lots of parts. XGBoost works with large, complicated datasets. XGBoost is an ensemble modelling technique.

# %%
model_xgb=xgb.XGBClassifier()
model_xgb.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
model_xgb.score(x_test,y_test)
# Out:
# 0.775

# %%
y_predict = model_xgb.predict(x_test)

performance = confusion_matrix(y_test,y_predict)

plot_confusion_matrix(model_xgb,x_test,y_test)
plt.show()

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.79      0.77        96
#            1       0.80      0.76      0.78       104
#
#     accuracy                           0.78       200
#    macro avg       0.78      0.78      0.77       200
# weighted avg       0.78      0.78      0.78       200

# %% [markdown]
# | Model | Accuracy Percentage |
# | --- | --- |
# | Logistic Regression | 68% |
# | DecisionTreeClassifier | 72% |
# | RandomForestClassifier | 77.5% |
# |Naive Bayes Classifier | 65% |
# |XGB | 75% |

# %% [markdown]
# ### From all the models Best Model is Random Forest Classifier and the Accuracy of model is .77
