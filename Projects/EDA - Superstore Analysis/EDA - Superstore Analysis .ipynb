# %% [markdown]
# ## Importing The Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Reading and Viewing the Data

# %%
d=pd.read_csv('superstore.csv',encoding='ISO-8859-1')

# %%
d
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2018-152156  08-11-2018  11-11-2018    Second Class
# 1          2  CA-2018-152156  08-11-2018  11-11-2018    Second Class
# 2          3  CA-2018-138688  12-06-2018  16-06-2018    Second Class
# 3          4  US-2017-108966  11-10-2017  18-10-2017  Standard Class
# 4          5  US-2017-108966  11-10-2017  18-10-2017  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2016-110422  21-01-2016  23-01-2016    Second Class
# 9990    9991  CA-2019-121258  26-02-2019  03-03-2019  Standard Class
# 9991    9992  CA-2019-121258  26-02-2019  03-03-2019  Standard Class
# 9992    9993  CA-2019-121258  26-02-2019  03-03-2019  Standard Class
# 9993    9994  CA-2019-119914  04-05-2019  09-05-2019    Second Class
#
#      Customer ID     Customer Name    Segment Country/Region             City  \
# ...

# %% [markdown]
# ## Shape of the Data

# %%
d.shape
# Out:
# (9994, 21)

# %% [markdown]
# ## To print fields name

# %%
d.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# ## To check the data type of attributes

# %%
d.dtypes
# Out:
# Row ID              int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# Country/Region     object
# City               object
# State              object
# Postal Code       float64
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# dtype: object

# %% [markdown]
# ## Checking if the Dataset contains Nullvalues

# %%
d.isnull()
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0      False     False       False      False      False        False
# 1      False     False       False      False      False        False
# 2      False     False       False      False      False        False
# 3      False     False       False      False      False        False
# 4      False     False       False      False      False        False
# ...      ...       ...         ...        ...        ...          ...
# 9989   False     False       False      False      False        False
# 9990   False     False       False      False      False        False
# 9991   False     False       False      False      False        False
# 9992   False     False       False      False      False        False
# 9993   False     False       False      False      False        False
#
#       Customer Name  Segment  Country/Region   City  ...  Postal Code  Region  \
# ...

# %%
d.isnull().sum()
# Out:
# Row ID             0
# Order ID           0
# Order Date         0
# Ship Date          0
# Ship Mode          0
# Customer ID        0
# Customer Name      0
# Segment            0
# Country/Region     0
# City               0
# State              0
# Postal Code       11
# Region             0
# Product ID         0
# Category           0
# Sub-Category       0
# Product Name       0
# Sales              0
# Quantity           0
# Discount           0
# Profit             0
# dtype: int64

# %% [markdown]
# ## Total number of null value

# %%
d.isnull().sum().sum()
# Out:
# 11

# %% [markdown]
# ## To print top 5 records

# %%
d.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2018-152156  08-11-2018  11-11-2018    Second Class    CG-12520
# 1       2  CA-2018-152156  08-11-2018  11-11-2018    Second Class    CG-12520
# 2       3  CA-2018-138688  12-06-2018  16-06-2018    Second Class    DV-13045
# 3       4  US-2017-108966  11-10-2017  18-10-2017  Standard Class    SO-20335
# 4       5  US-2017-108966  11-10-2017  18-10-2017  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
d.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2018-152156  08-11-2018  11-11-2018    Second Class    CG-12520
# 1       2  CA-2018-152156  08-11-2018  11-11-2018    Second Class    CG-12520
# 2       3  CA-2018-138688  12-06-2018  16-06-2018    Second Class    DV-13045
# 3       4  US-2017-108966  11-10-2017  18-10-2017  Standard Class    SO-20335
# 4       5  US-2017-108966  11-10-2017  18-10-2017  Standard Class    SO-20335
# 5       6  CA-2016-115812  09-06-2016  14-06-2016  Standard Class    BH-11710
# 6       7  CA-2016-115812  09-06-2016  14-06-2016  Standard Class    BH-11710
# 7       8  CA-2016-115812  09-06-2016  14-06-2016  Standard Class    BH-11710
# 8       9  CA-2016-115812  09-06-2016  14-06-2016  Standard Class    BH-11710
# 9      10  CA-2016-115812  09-06-2016  14-06-2016  Standard Class    BH-11710
#
#      Customer Name    Segment Country/Region             City  ...  \
# ...

# %% [markdown]
# ## To print bottom 5 records

# %%
d.tail()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9989    9990  CA-2016-110422  21-01-2016  23-01-2016    Second Class
# 9990    9991  CA-2019-121258  26-02-2019  03-03-2019  Standard Class
# 9991    9992  CA-2019-121258  26-02-2019  03-03-2019  Standard Class
# 9992    9993  CA-2019-121258  26-02-2019  03-03-2019  Standard Class
# 9993    9994  CA-2019-119914  04-05-2019  09-05-2019    Second Class
#
#      Customer ID     Customer Name   Segment Country/Region         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
d.tail(10)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9984    9985  CA-2017-100251  17-05-2017  23-05-2017  Standard Class
# 9985    9986  CA-2017-100251  17-05-2017  23-05-2017  Standard Class
# 9986    9987  CA-2018-125794  29-09-2018  03-10-2018  Standard Class
# 9987    9988  CA-2019-163629  17-11-2019  21-11-2019  Standard Class
# 9988    9989  CA-2019-163629  17-11-2019  21-11-2019  Standard Class
# 9989    9990  CA-2016-110422  21-01-2016  23-01-2016    Second Class
# 9990    9991  CA-2019-121258  26-02-2019  03-03-2019  Standard Class
# 9991    9992  CA-2019-121258  26-02-2019  03-03-2019  Standard Class
# 9992    9993  CA-2019-121258  26-02-2019  03-03-2019  Standard Class
# 9993    9994  CA-2019-119914  04-05-2019  09-05-2019    Second Class
#
#      Customer ID     Customer Name    Segment Country/Region         City  \
# 9984    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# ...

# %% [markdown]
# ## Print Basic information of a dataset

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   object
#  3   Ship Date       9994 non-null   object
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
#  16  Product Name    9994 non-null   object
# ...

# %% [markdown]
# ## Droping the columns which is not required

# %%
d.drop(['Row ID'], axis=1 ,inplace=True)
d
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2018-152156  08-11-2018  11-11-2018    Second Class    CG-12520
# 1     CA-2018-152156  08-11-2018  11-11-2018    Second Class    CG-12520
# 2     CA-2018-138688  12-06-2018  16-06-2018    Second Class    DV-13045
# 3     US-2017-108966  11-10-2017  18-10-2017  Standard Class    SO-20335
# 4     US-2017-108966  11-10-2017  18-10-2017  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9989  CA-2016-110422  21-01-2016  23-01-2016    Second Class    TB-21400
# 9990  CA-2019-121258  26-02-2019  03-03-2019  Standard Class    DB-13060
# 9991  CA-2019-121258  26-02-2019  03-03-2019  Standard Class    DB-13060
# 9992  CA-2019-121258  26-02-2019  03-03-2019  Standard Class    DB-13060
# 9993  CA-2019-119914  04-05-2019  09-05-2019    Second Class    CC-12220
#
#          Customer Name    Segment Country/Region             City       State  \
# ...

# %%
d.drop(['Postal Code'], axis=1 , inplace=True)
d
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2018-152156  08-11-2018  11-11-2018    Second Class    CG-12520
# 1     CA-2018-152156  08-11-2018  11-11-2018    Second Class    CG-12520
# 2     CA-2018-138688  12-06-2018  16-06-2018    Second Class    DV-13045
# 3     US-2017-108966  11-10-2017  18-10-2017  Standard Class    SO-20335
# 4     US-2017-108966  11-10-2017  18-10-2017  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9989  CA-2016-110422  21-01-2016  23-01-2016    Second Class    TB-21400
# 9990  CA-2019-121258  26-02-2019  03-03-2019  Standard Class    DB-13060
# 9991  CA-2019-121258  26-02-2019  03-03-2019  Standard Class    DB-13060
# 9992  CA-2019-121258  26-02-2019  03-03-2019  Standard Class    DB-13060
# 9993  CA-2019-119914  04-05-2019  09-05-2019    Second Class    CC-12220
#
#          Customer Name    Segment Country/Region             City       State  \
# ...

# %%
d.shape
# Out:
# (9994, 19)

# %% [markdown]
# ## Statistical information of the Data

# %%
d.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ## To check is there any Duplicate value

# %%
d.duplicated().sum()
# Out:
# 1

# %%
d=d.drop_duplicates()

# %%
d
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2018-152156  08-11-2018  11-11-2018    Second Class    CG-12520
# 1     CA-2018-152156  08-11-2018  11-11-2018    Second Class    CG-12520
# 2     CA-2018-138688  12-06-2018  16-06-2018    Second Class    DV-13045
# 3     US-2017-108966  11-10-2017  18-10-2017  Standard Class    SO-20335
# 4     US-2017-108966  11-10-2017  18-10-2017  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9989  CA-2016-110422  21-01-2016  23-01-2016    Second Class    TB-21400
# 9990  CA-2019-121258  26-02-2019  03-03-2019  Standard Class    DB-13060
# 9991  CA-2019-121258  26-02-2019  03-03-2019  Standard Class    DB-13060
# 9992  CA-2019-121258  26-02-2019  03-03-2019  Standard Class    DB-13060
# 9993  CA-2019-119914  04-05-2019  09-05-2019    Second Class    CC-12220
#
#          Customer Name    Segment Country/Region             City       State  \
# ...

# %% [markdown]
# ## drop a column

# %%
d=d.drop(['Order ID'],axis=1)
d
# Out:
#       Order Date   Ship Date       Ship Mode Customer ID     Customer Name  \
# 0     08-11-2018  11-11-2018    Second Class    CG-12520       Claire Gute
# 1     08-11-2018  11-11-2018    Second Class    CG-12520       Claire Gute
# 2     12-06-2018  16-06-2018    Second Class    DV-13045   Darrin Van Huff
# 3     11-10-2017  18-10-2017  Standard Class    SO-20335    Sean O'Donnell
# 4     11-10-2017  18-10-2017  Standard Class    SO-20335    Sean O'Donnell
# ...          ...         ...             ...         ...               ...
# 9989  21-01-2016  23-01-2016    Second Class    TB-21400  Tom Boeckenhauer
# 9990  26-02-2019  03-03-2019  Standard Class    DB-13060       Dave Brooks
# 9991  26-02-2019  03-03-2019  Standard Class    DB-13060       Dave Brooks
# 9992  26-02-2019  03-03-2019  Standard Class    DB-13060       Dave Brooks
# 9993  04-05-2019  09-05-2019    Second Class    CC-12220      Chris Cortes
#
# ...

# %% [markdown]
# ## Print some random lines

# %%
d.sample(4)
# Out:
#       Order Date   Ship Date       Ship Mode Customer ID     Customer Name  \
# 8132  20-07-2016  23-07-2016     First Class    JD-15895  Jonathan Doherty
# 2438  18-11-2016  20-11-2016    Second Class    PW-19240      Pierre Wener
# 2077  12-09-2019  15-09-2019     First Class    BF-11080         Bart Folk
# 8544  27-03-2018  31-03-2018  Standard Class    DS-13180       David Smith
#
#         Segment Country/Region        City       State Region  \
# 8132  Corporate  United States   Riverside  California   West
# 2438   Consumer  United States  Louisville    Colorado   West
# 2077   Consumer  United States   Baltimore    Maryland   East
# 8544  Corporate  United States    Columbus     Georgia  South
#
#            Product ID         Category Sub-Category  \
# 8132  OFF-ST-10001490  Office Supplies      Storage
# 2438  OFF-PA-10002259  Office Supplies        Paper
# 2077  OFF-AP-10000358  Office Supplies   Appliances
# 8544  FUR-FU-10004053        Furniture  Furnishings
#
# ...

# %% [markdown]
# ## Printing the number of unique values for each columns

# %%
d.nunique()
# Out:
# Order Date        1236
# Ship Date         1334
# Ship Mode            4
# Customer ID        793
# Customer Name      793
# Segment              3
# Country/Region       1
# City               531
# State               49
# Region               4
# Product ID        1862
# Category             3
# Sub-Category        17
# Product Name      1850
# Sales             5825
# Quantity            14
# Discount            12
# Profit            7287
# dtype: int64

# %% [markdown]
# ## Correlation and Covariance

# %%
d.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200808 -0.028197  0.479067
# Quantity  0.200808  1.000000  0.008680  0.066241
# Discount -0.028197  0.008680  1.000000 -0.219481
# Profit    0.479067  0.066241 -0.219481  1.000000

# %%
d.cov()
# Out:
#                   Sales    Quantity   Discount        Profit
# Sales     388473.064245  278.497018  -3.628333  69951.306527
# Quantity     278.497018    4.951288   0.003987     34.530932
# Discount      -3.628333    0.003987   0.042625    -10.615649
# Profit     69951.306527   34.530932 -10.615649  54883.124303

# %% [markdown]
# ## To count number of categories

# %%
d['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2120
# Technology         1847
# Name: Category, dtype: int64

# %%
d['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
d['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
d['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
d['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
d1=d.copy()
d1=d1.pivot_table('Profit',columns='Region',aggfunc='sum')
d1
# Out:
# Region     Central        East       South         West
# Profit  39706.3625  91534.8388  46749.4303  108418.4489

# %%
d2=d.copy()
d2=d2.pivot_table('Sales',columns='Region',aggfunc='sum')
d2
# Out:
# Region      Central        East       South         West
# Sales   501239.8908  678499.868  391721.905  725457.8245

# %%
d3=d.copy()
d3=d3.pivot_table('Profit',columns='Region',aggfunc='max')
d3
# Out:
# Region   Central       East     South       West
# Profit  8399.976  5039.9856  3177.475  6719.9808

# %%
d4=d.copy()
d4
# Out:
#       Order Date   Ship Date       Ship Mode Customer ID     Customer Name  \
# 0     08-11-2018  11-11-2018    Second Class    CG-12520       Claire Gute
# 1     08-11-2018  11-11-2018    Second Class    CG-12520       Claire Gute
# 2     12-06-2018  16-06-2018    Second Class    DV-13045   Darrin Van Huff
# 3     11-10-2017  18-10-2017  Standard Class    SO-20335    Sean O'Donnell
# 4     11-10-2017  18-10-2017  Standard Class    SO-20335    Sean O'Donnell
# ...          ...         ...             ...         ...               ...
# 9989  21-01-2016  23-01-2016    Second Class    TB-21400  Tom Boeckenhauer
# 9990  26-02-2019  03-03-2019  Standard Class    DB-13060       Dave Brooks
# 9991  26-02-2019  03-03-2019  Standard Class    DB-13060       Dave Brooks
# 9992  26-02-2019  03-03-2019  Standard Class    DB-13060       Dave Brooks
# 9993  04-05-2019  09-05-2019    Second Class    CC-12220      Chris Cortes
#
# ...

# %%
d4['Sales']=d['Sales']*d['Quantity']
d4['Sales']
# Out:
# 0        523.9200
# 1       2195.8200
# 2         29.2400
# 3       4787.8875
# 4         44.7360
#           ...
# 9989      75.7440
# 9990     183.9200
# 9991     517.1520
# 9992     118.4000
# 9993     486.3200
# Name: Sales, Length: 9993, dtype: float64

# %%
d4
# Out:
#       Order Date   Ship Date       Ship Mode Customer ID     Customer Name  \
# 0     08-11-2018  11-11-2018    Second Class    CG-12520       Claire Gute
# 1     08-11-2018  11-11-2018    Second Class    CG-12520       Claire Gute
# 2     12-06-2018  16-06-2018    Second Class    DV-13045   Darrin Van Huff
# 3     11-10-2017  18-10-2017  Standard Class    SO-20335    Sean O'Donnell
# 4     11-10-2017  18-10-2017  Standard Class    SO-20335    Sean O'Donnell
# ...          ...         ...             ...         ...               ...
# 9989  21-01-2016  23-01-2016    Second Class    TB-21400  Tom Boeckenhauer
# 9990  26-02-2019  03-03-2019  Standard Class    DB-13060       Dave Brooks
# 9991  26-02-2019  03-03-2019  Standard Class    DB-13060       Dave Brooks
# 9992  26-02-2019  03-03-2019  Standard Class    DB-13060       Dave Brooks
# 9993  04-05-2019  09-05-2019    Second Class    CC-12220      Chris Cortes
#
# ...

# %%
d4=d4.groupby(['Category'])['Sales'].sum()
d4=pd.DataFrame(d4)
d4
# Out:
#                         Sales
# Category
# Furniture        3.858652e+06
# Office Supplies  3.548585e+06
# Technology       4.080262e+06

# %%
n=d.groupby('Category').Sales.sum().sort_values(ascending=False)
n
# Out:
# Category
# Technology         836154.0330
# Furniture          741718.4233
# Office Supplies    719047.0320
# Name: Sales, dtype: float64

# %%
n=d.groupby('Sub-Category').Sales.sum().sort_values(ascending=False)
n
# Out:
# Sub-Category
# Phones         330007.0540
# Chairs         328167.7310
# Storage        223843.6080
# Tables         206965.5320
# Binders        203412.7330
# Machines       189238.6310
# Accessories    167380.3180
# Copiers        149528.0300
# Bookcases      114879.9963
# Appliances     107532.1610
# Furnishings     91705.1640
# Paper           78479.2060
# Supplies        46673.5380
# Art             27118.7920
# Envelopes       16476.4020
# Labels          12486.3120
# Fasteners        3024.2800
# Name: Sales, dtype: float64

# %%
n.head()
# Out:
# Sub-Category
# Phones     330007.054
# Chairs     328167.731
# Storage    223843.608
# Tables     206965.532
# Binders    203412.733
# Name: Sales, dtype: float64

# %%
pd.crosstab(d['Segment'],d['Region'])
# Out:
# Region       Central  East  South  West
# Segment
# Consumer        1212  1469    838  1672
# Corporate        673   877    510   960
# Home Office      438   501    272   571

# %%
d.sort_values(by=['Category'])
# Out:
#       Order Date   Ship Date       Ship Mode Customer ID     Customer Name  \
# 0     08-11-2018  11-11-2018    Second Class    CG-12520       Claire Gute
# 8133  08-10-2017  13-10-2017  Standard Class    GH-14485         Gene Hale
# 1903  21-10-2019  22-10-2019     First Class    DK-12835   Damala Kotsonis
# 6151  18-03-2016  21-03-2016    Second Class    EK-13795     Eileen Kiefer
# 6153  20-04-2019  23-04-2019     First Class    CV-12805     Cynthia Voltz
# ...          ...         ...             ...         ...               ...
# 1844  29-07-2019  02-08-2019  Standard Class    GW-14605  Giulietta Weimer
# 3921  28-06-2018  02-07-2018    Second Class    RF-19735      Roland Fjeld
# 6173  02-08-2016  08-08-2016  Standard Class    NZ-18565     Nick Zandusky
# 8348  30-04-2017  04-05-2017  Standard Class    JW-15220         Jane Waco
# 2522  15-10-2018  21-10-2018  Standard Class    CD-12790   Cynthia Delaney
#
# ...

# %%
grouped=pd.DataFrame(d.groupby(['Ship Mode','Segment','Category','Sub-Category','State','Region'])['Quantity','Discount','Sales','Profit'].sum().reset_index())
grouped
# Out:
#            Ship Mode      Segment    Category Sub-Category       State  \
# 0        First Class     Consumer   Furniture    Bookcases     Arizona
# 1        First Class     Consumer   Furniture    Bookcases  California
# 2        First Class     Consumer   Furniture    Bookcases    Colorado
# 3        First Class     Consumer   Furniture    Bookcases     Florida
# 4        First Class     Consumer   Furniture    Bookcases     Georgia
# ...              ...          ...         ...          ...         ...
# 2978  Standard Class  Home Office  Technology       Phones       Texas
# 2979  Standard Class  Home Office  Technology       Phones     Vermont
# 2980  Standard Class  Home Office  Technology       Phones    Virginia
# 2981  Standard Class  Home Office  Technology       Phones  Washington
# 2982  Standard Class  Home Office  Technology       Phones   Wisconsin
#
#        Region  Quantity  Discount     Sales    Profit
# 0        West         5      0.70   181.470 -320.5970
# ...

# %%
d_shipmode =d[['Ship Mode','Category','Quantity']].groupby (['Ship Mode','Category']).sum('Quantity')
d_shipmode
# Out:
#                                 Quantity
# Ship Mode      Category
# First Class    Furniture            1238
#                Office Supplies      3372
#                Technology           1083
# Same Day       Furniture             453
#                Office Supplies      1147
#                Technology            360
# Second Class   Furniture            1569
#                Office Supplies      4480
#                Technology           1374
# Standard Class Furniture            4766
#                Office Supplies     13907
#                Technology           4122

# %%
state_sales_d = pd.pivot_table(data=d[['State','Sales']],
                                index=['State'],
                               values='Sales',aggfunc='max')
state_sales_d.sort_values(by='Sales',ascending=False).head(10)
# Out:
#                   Sales
# State
# Florida       22638.480
# Indiana       17499.950
# Washington    13999.960
# New York      11199.968
# Delaware      10499.970
# Michigan       9892.740
# Minnesota      9449.950
# New Jersey     9099.930
# Virginia       8749.950
# Pennsylvania   8399.976

# %%
state_profit_d = pd.pivot_table(data=d[['State','Profit']],
                                index=['State'],
                               values='Profit',aggfunc='max')
state_profit_d.sort_values(by='Profit',ascending=False).head(10)
# Out:
#                  Profit
# State
# Indiana       8399.9760
# Washington    6719.9808
# Delaware      5039.9856
# Michigan      4946.3700
# Minnesota     4630.4755
# New York      3919.9888
# Georgia       3177.4750
# Virginia      2799.9840
# Rhode Island  2591.9568
# New Jersey    2365.9818

# %%
d_Category_sales = pd.pivot_table(data=d[['Category','Sub-Category','Sales']],
                                index=['Category','Sub-Category'],
                               values='Sales',aggfunc='max')
d_Category_sales
# Out:
#                                   Sales
# Category        Sub-Category
# Furniture       Bookcases      4404.900
#                 Chairs         4416.174
#                 Furnishings    1336.440
#                 Tables         4297.644
# Office Supplies Appliances     2625.120
#                 Art            1113.024
#                 Binders        9892.740
#                 Envelopes       604.656
#                 Fasteners        93.360
#                 Labels          786.480
#                 Paper           733.950
#                 Storage        2934.330
#                 Supplies       8187.650
# Technology      Accessories    3347.370
#                 Copiers       17499.950
#                 Machines      22638.480
#                 Phones         4548.810

# %%
d_Category_quantity = pd.pivot_table(data=d[['Category','Sub-Category','Quantity']],
                                index=['Category','Sub-Category'],
                               values='Quantity',aggfunc='sum')
d_Category_quantity
# Out:
#                               Quantity
# Category        Sub-Category
# Furniture       Bookcases          868
#                 Chairs            2354
#                 Furnishings       3563
#                 Tables            1241
# Office Supplies Appliances        1729
#                 Art               3000
#                 Binders           5974
#                 Envelopes          906
#                 Fasteners          914
#                 Labels            1400
#                 Paper             5178
#                 Storage           3158
#                 Supplies           647
# Technology      Accessories       2976
#                 Copiers            234
#                 Machines           440
#                 Phones            3289

# %%
d_Category_profit = pd.pivot_table(data=d[['Category','Sub-Category','Profit']],
                                index=['Category','Sub-Category'],
                               values='Profit',aggfunc='max')
d_Category_profit
# Out:
#                                  Profit
# Category        Sub-Category
# Furniture       Bookcases     1013.1270
#                 Chairs         770.3520
#                 Furnishings    387.5676
#                 Tables         629.0100
# Office Supplies Appliances     793.7160
#                 Art            112.5740
#                 Binders       4946.3700
#                 Envelopes      204.0714
#                 Fasteners       21.8880
#                 Labels         385.3752
#                 Paper          352.2960
#                 Storage        792.2691
#                 Supplies       327.5060
# Technology      Accessories    829.3754
#                 Copiers       8399.9760
#                 Machines      2799.9840
#                 Phones        1228.1787

# %%
d['Revenue'] = d['Sales'] - d['Profit']
d
# Out:
#       Order Date   Ship Date       Ship Mode Customer ID     Customer Name  \
# 0     08-11-2018  11-11-2018    Second Class    CG-12520       Claire Gute
# 1     08-11-2018  11-11-2018    Second Class    CG-12520       Claire Gute
# 2     12-06-2018  16-06-2018    Second Class    DV-13045   Darrin Van Huff
# 3     11-10-2017  18-10-2017  Standard Class    SO-20335    Sean O'Donnell
# 4     11-10-2017  18-10-2017  Standard Class    SO-20335    Sean O'Donnell
# ...          ...         ...             ...         ...               ...
# 9989  21-01-2016  23-01-2016    Second Class    TB-21400  Tom Boeckenhauer
# 9990  26-02-2019  03-03-2019  Standard Class    DB-13060       Dave Brooks
# 9991  26-02-2019  03-03-2019  Standard Class    DB-13060       Dave Brooks
# 9992  26-02-2019  03-03-2019  Standard Class    DB-13060       Dave Brooks
# 9993  04-05-2019  09-05-2019    Second Class    CC-12220      Chris Cortes
#
# ...

# %%
d['GrossPrice'] = (d['Revenue'] - d['Profit']) / d['Quantity']

# %%
d.head(10)
# Out:
#    Order Date   Ship Date       Ship Mode Customer ID    Customer Name  \
# 0  08-11-2018  11-11-2018    Second Class    CG-12520      Claire Gute
# 1  08-11-2018  11-11-2018    Second Class    CG-12520      Claire Gute
# 2  12-06-2018  16-06-2018    Second Class    DV-13045  Darrin Van Huff
# 3  11-10-2017  18-10-2017  Standard Class    SO-20335   Sean O'Donnell
# 4  11-10-2017  18-10-2017  Standard Class    SO-20335   Sean O'Donnell
# 5  09-06-2016  14-06-2016  Standard Class    BH-11710  Brosina Hoffman
# 6  09-06-2016  14-06-2016  Standard Class    BH-11710  Brosina Hoffman
# 7  09-06-2016  14-06-2016  Standard Class    BH-11710  Brosina Hoffman
# 8  09-06-2016  14-06-2016  Standard Class    BH-11710  Brosina Hoffman
# 9  09-06-2016  14-06-2016  Standard Class    BH-11710  Brosina Hoffman
#
#      Segment Country/Region             City       State Region  \
# 0   Consumer  United States        Henderson    Kentucky  South
# ...

# %% [markdown]
# ## Visualization

# %%
plt.bar(d['Quantity'],d['Profit'])
plt.title('Profit Vs Quantity',fontsize=15,color='red')
plt.xlabel('Quantity',fontsize=15)
plt.ylabel('Profit',fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(18,5))
plt.bar('Sub-Category','Category',data=d,color='green')
plt.show()

# %%
print(d['Sub-Category'].value_counts())
plt.figure(figsize=(10,4))
sns.countplot(x=d['Sub-Category'])
plt.xticks(rotation=90)
plt.show()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          616
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
print(d['State'].value_counts())
plt.figure(figsize=(15,4))
sns.countplot(x=d['State'])
plt.xticks(rotation=90)
plt.show()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     468
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
plt.bar(d['Quantity'],d['Sales'],color="red")
plt.title('Sales Vs Quantity',fontsize=15,color='blue')
plt.xlabel('Quantity',fontsize=15)
plt.grid(True)
plt.show()

# %%
sns.relplot(x='Quantity',y='Profit',hue='Segment',data=d)
plt.show()

# %%
sns.countplot(x='Segment',data=d,palette='coolwarm')
plt.show()

# %%
plt.title('Segment',fontsize=20)
d['Segment'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %%
sns.countplot(x='Category',data=d,palette='tab10')
plt.show()

# %%
d.groupby('Segment')[['Profit','Sales']].sum().plot.bar(color=['red','blue'],figsize=(8,5))
plt.ylabel('Profit/Loss and sales')
plt.show()

# %%
plt.title('Region',fontsize=20)
d['Region'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.title('Segment wise Sales in each region')
sns.barplot(x='Region',y='Sales',data=d,hue='Segment',palette='coolwarm_r')
plt.xlabel('Region',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.title('Segment wise Sales in each region')
sns.barplot(x='Region',y='Sales',data=d,palette='coolwarm_r')
plt.xlabel('Region',fontsize=15)
plt.show()

# %%
d['Region'].value_counts()
# Out:
# West       3203
# East       2847
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.title('Segment wise Sales in each region')
sns.barplot(x='Region',y='Sales',data=d,hue='Segment',order=d['Region'].value_counts().index,palette='coolwarm_r')
plt.xlabel('Region',fontsize=15)
plt.show()

# %%
d.groupby('Region')[['Profit','Sales']].sum().plot.bar(color=['green','orange'],figsize=(8,5))
plt.ylabel('Profit/Loss and sales')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='State',data=d,palette='rocket_r',order=d['State'].value_counts().index)
plt.xlabel('States',fontsize=25)
plt.xticks(rotation=70)
plt.show()

# %%
sns.countplot(x='State',data=d,palette='rocket_r',order=d['State'].value_counts().index)
plt.xlabel('States',fontsize=25)
plt.xticks(rotation=70)
plt.show()

# %%
n_data=['Sales','Quantity','Discount','Profit']
plt.figure(figsize=(10,5))
sns.heatmap(d[n_data].corr(),annot=True,fmt='.4f',cmap='coolwarm_r',center=0)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.lineplot('Discount','Profit',data=d,color='r',label='Discount')
plt.legend()
plt.show()

# %%
d
# Out:
#       Order Date   Ship Date       Ship Mode Customer ID     Customer Name  \
# 0     08-11-2018  11-11-2018    Second Class    CG-12520       Claire Gute
# 1     08-11-2018  11-11-2018    Second Class    CG-12520       Claire Gute
# 2     12-06-2018  16-06-2018    Second Class    DV-13045   Darrin Van Huff
# 3     11-10-2017  18-10-2017  Standard Class    SO-20335    Sean O'Donnell
# 4     11-10-2017  18-10-2017  Standard Class    SO-20335    Sean O'Donnell
# ...          ...         ...             ...         ...               ...
# 9989  21-01-2016  23-01-2016    Second Class    TB-21400  Tom Boeckenhauer
# 9990  26-02-2019  03-03-2019  Standard Class    DB-13060       Dave Brooks
# 9991  26-02-2019  03-03-2019  Standard Class    DB-13060       Dave Brooks
# 9992  26-02-2019  03-03-2019  Standard Class    DB-13060       Dave Brooks
# 9993  04-05-2019  09-05-2019    Second Class    CC-12220      Chris Cortes
#
# ...

# %%
d.dtypes
# Out:
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# Country/Region     object
# City               object
# State              object
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# Revenue           float64
# GrossPrice        float64
# dtype: object

# %%
d.hist(bins=20,figsize=(20,15),color='red')
plt.show()

# %%
d.hist(bins=50,figsize=(20,15),color='red')
plt.show()

# %%
sns.pairplot(d,hue='Category')
plt.show()

# %%
sns.pairplot(d)
plt.show()

# %%
sns.pairplot(d,hue='Segment')
plt.show()

# %%
d
# Out:
#       Order Date   Ship Date       Ship Mode Customer ID     Customer Name  \
# 0     08-11-2018  11-11-2018    Second Class    CG-12520       Claire Gute
# 1     08-11-2018  11-11-2018    Second Class    CG-12520       Claire Gute
# 2     12-06-2018  16-06-2018    Second Class    DV-13045   Darrin Van Huff
# 3     11-10-2017  18-10-2017  Standard Class    SO-20335    Sean O'Donnell
# 4     11-10-2017  18-10-2017  Standard Class    SO-20335    Sean O'Donnell
# ...          ...         ...             ...         ...               ...
# 9989  21-01-2016  23-01-2016    Second Class    TB-21400  Tom Boeckenhauer
# 9990  26-02-2019  03-03-2019  Standard Class    DB-13060       Dave Brooks
# 9991  26-02-2019  03-03-2019  Standard Class    DB-13060       Dave Brooks
# 9992  26-02-2019  03-03-2019  Standard Class    DB-13060       Dave Brooks
# 9993  04-05-2019  09-05-2019    Second Class    CC-12220      Chris Cortes
#
# ...

# %%
d.to_excel('superanalysis.xls',index=False)
